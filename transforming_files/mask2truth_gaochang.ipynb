# %%
import os
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# %%
stack_name = "14. 08Oct2019P1"
paras_dir  = "/home/haobo/Documents/UROP2021/"+stack_name+"/paras/"
mask_dir = "/home/haobo/Documents/UROP2021/Truth_pics_19Jul/diseased_Data/masks/"
# orig_path = paras_dir + "para{}_new/time{:03d}.png"
# orig_path = paras_dir + '../time{1:03d}/slice{0:03d}time{1:03d}.png'
truth_mask_path = "/home/haobo/Documents/UROP2021/"
truth_pic_path  = "/home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_f_new/"

# %%
def rotate(image, angle, center=None, scale=1.0):
    # 获取图像尺寸
    (h, w) = image.shape[:2]
 
    # 若未指定旋转中心，则将图像中心设为旋转中心
    if center is None:
        center = (w / 2, h / 2)
 
    # 执行旋转
    M = cv2.getRotationMatrix2D(center, angle, scale)
    rotated = cv2.warpAffine(image, M, (w, h))
 
    # 返回旋转后的图像
    return rotated

# %%
def cut_resize_file(img_mat, cut_size=(512, 512)):
    # 根据最短边进行图像裁剪
    sp = img_mat.shape
    rows = sp[0]  # height(rows) of image
    cols = sp[1]  # width(colums) of image
    if rows >= cols:
        shorter = cols
    else:
        shorter = rows
    cropped = img_mat[0:shorter, 0:shorter]  # 裁剪坐标为[y0:y1, x0:x1]
    new_array = cv2.resize(cropped, cut_size)
    return new_array

# %%
a = cv2.imread('/home/haobo/Documents/UROP2021/Truth_pics_19Jul/diseased_Data/masks/91_20_slice019time039.png', 0)
cv2.imshow('', a)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# print(mask_dir)
mask_dirs = os.listdir(mask_dir)
masks = []
for f in mask_dirs:
    mask = cv2.imread(mask_dir + f)
    # print(mask)
    if mask is not None:
        # mask //= 127
        # mask = np.uint8(cut_resize_file(mask))
        # mask = rotate(mask, 270)
        # mask = cv2.flip(mask, 0)
        new_mask = np.uint8(mask > 127) + 2 * np.uint8(mask==127)
        masks.append(new_mask)

# %%
print(np.unique(masks[1]))
plt.imshow(np.uint8(masks[1]==2)*100)
# Out:
# [0 1 2]

# %%
plt.imshow(masks[1]*100)
print(masks[1].min())
plt.show()
# Out:
# 0

# %%
for f, mask in zip(mask_dirs, masks):
    f_name = truth_mask_path + stack_name + '_' + f
    print(f_name)
    cv2.imwrite(f_name, mask)
# Out:
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time001.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time002.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time003.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time004.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time005.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time006.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time007.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time008.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time009.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time010.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time011.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time012.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time013.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time014.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time015.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time016.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time017.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time018.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time019.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time020.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time021.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time022.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time023.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time024.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time025.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time026.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time027.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time028.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time029.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time030.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time031.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time032.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time033.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time034.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time035.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time036.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time037.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time038.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time039.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice016time040.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time001.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time002.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time003.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time004.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time005.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time006.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time007.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time008.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time009.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time010.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time011.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time012.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time013.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time014.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time015.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time016.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time017.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time018.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time019.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time020.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time021.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time022.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time023.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time024.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time025.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time026.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time027.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time028.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time029.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time030.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time031.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time032.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time033.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time034.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time035.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time036.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time037.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time038.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time039.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice017time040.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time001.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time002.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time003.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time004.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time005.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time006.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time007.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time008.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time009.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time010.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time011.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time012.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time013.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time014.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time015.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time016.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time017.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time018.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time019.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time020.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time021.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time022.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time023.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time024.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time025.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time026.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time027.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time028.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time029.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time030.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time031.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time032.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time033.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time034.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time035.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time036.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time037.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time038.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time039.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice018time040.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time001.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time002.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time003.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time004.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time005.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time006.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time007.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time008.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time009.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time010.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time011.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time012.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time013.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time014.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time015.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time016.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time017.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time018.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time019.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time020.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time021.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time022.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time023.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time024.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time025.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time026.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time027.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time028.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time029.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time030.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time031.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time032.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time033.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time034.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time035.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time036.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time037.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time038.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time039.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice019time040.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time001.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time002.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time003.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time004.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time005.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time006.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time007.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time008.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time009.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time010.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time011.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time012.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time013.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time014.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time015.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time016.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time017.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time018.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time019.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time020.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time021.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time022.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time023.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time024.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time025.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time026.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time027.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time028.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time029.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time030.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time031.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time032.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time033.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time034.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time035.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time036.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time037.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time038.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time039.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice020time040.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time001.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time002.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time003.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time004.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time005.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time006.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time007.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time008.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time009.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time010.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time011.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time012.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time013.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time014.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time015.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time016.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time017.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time018.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time019.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time020.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time021.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time022.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time023.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time024.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time025.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time026.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time027.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time028.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time029.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time030.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time031.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time032.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time033.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time034.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time035.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time036.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time037.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time038.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time039.png
# /home/haobo/Documents/UROP2021/HaoboSeg-onthefly-08Oct2019P1/test_m_new/14. 08Oct2019P1_slice021time040.png

# %%
start_slice =15
end_slice = 21
start_t = 1
end_t = 40

for s in range(start_slice, end_slice + 1):
    for t in range(start_t, end_t + 1):
        print(orig_path.format(s, t))
        pic = cv2.imread(orig_path.format(s, t))
        # pic = pic[40:390, 40:476-30, ...]
        print(pic.shape)
        pic = cut_resize_file(pic)
        # pic = rotate(pic, 270)
        pic = cv2.flip(pic, 0)
        # print(orig_path.format(s, t))
        cv2.imwrite(truth_pic_path \
                  + stack_name + f'_slice{s:03d}time{t:03d}.png', pic)
        # img_w_mask = np.uint8(pic*0.8 + masks[-1]*20)
        # plt.imshow(img_w_mask)
        # plt.show
# Out:
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time001.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time002.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time003.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time004.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time005.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time006.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time007.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time008.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time009.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time010.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time011.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time012.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time013.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time014.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time015.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time016.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time017.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time018.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time019.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time020.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time021.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time022.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time023.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time024.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time025.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time026.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time027.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time028.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time029.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time030.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time031.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time032.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time033.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time034.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time035.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time036.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time037.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time038.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time039.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para15_new/time040.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time001.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time002.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time003.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time004.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time005.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time006.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time007.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time008.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time009.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time010.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time011.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time012.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time013.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time014.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time015.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time016.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time017.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time018.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time019.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time020.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time021.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time022.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time023.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time024.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time025.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time026.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time027.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time028.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time029.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time030.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time031.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time032.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time033.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time034.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time035.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time036.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time037.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time038.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time039.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para16_new/time040.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time001.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time002.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time003.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time004.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time005.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time006.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time007.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time008.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time009.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time010.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time011.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time012.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time013.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time014.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time015.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time016.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time017.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time018.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time019.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time020.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time021.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time022.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time023.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time024.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time025.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time026.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time027.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time028.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time029.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time030.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time031.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time032.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time033.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time034.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time035.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time036.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time037.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time038.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time039.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para17_new/time040.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time001.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time002.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time003.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time004.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time005.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time006.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time007.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time008.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time009.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time010.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time011.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time012.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time013.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time014.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time015.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time016.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time017.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time018.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time019.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time020.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time021.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time022.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time023.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time024.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time025.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time026.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time027.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time028.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time029.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time030.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time031.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time032.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time033.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time034.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time035.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time036.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time037.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time038.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time039.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para18_new/time040.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time001.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time002.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time003.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time004.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time005.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time006.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time007.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time008.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time009.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time010.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time011.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time012.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time013.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time014.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time015.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time016.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time017.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time018.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time019.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time020.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time021.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time022.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time023.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time024.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time025.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time026.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time027.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time028.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time029.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time030.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time031.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time032.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time033.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time034.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time035.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time036.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time037.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time038.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time039.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para19_new/time040.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time001.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time002.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time003.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time004.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time005.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time006.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time007.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time008.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time009.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time010.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time011.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time012.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time013.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time014.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time015.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time016.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time017.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time018.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time019.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time020.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time021.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time022.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time023.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time024.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time025.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time026.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time027.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time028.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time029.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time030.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time031.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time032.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time033.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time034.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time035.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time036.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time037.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time038.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time039.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para20_new/time040.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time001.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time002.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time003.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time004.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time005.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time006.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time007.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time008.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time009.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time010.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time011.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time012.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time013.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time014.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time015.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time016.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time017.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time018.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time019.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time020.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time021.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time022.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time023.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time024.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time025.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time026.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time027.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time028.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time029.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time030.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time031.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time032.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time033.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time034.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time035.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time036.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time037.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time038.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time039.png
# (398, 435, 3)
# /home/haobo/Documents/UROP2021/14. 08Oct2019P1/paras/para21_new/time040.png
# (398, 435, 3)

# %%
plt.imshow(pic)
plt.show()

# %%
print(mask.shape)
# Out:
# (512, 512, 3)

# %%
mask = cv2.imread(mask_dir + f)
pic = cv2.imread(orig_path.format(s, t))
print(mask.shape, pic.shape)
# Out:
# (398, 435, 3) (398, 435, 3)

# %%
a = cv2.imread("/home/haobo/Documents/UROP2021/HaoboSeg/train_f/06042021P1_1_slice040time005.png")
b = cv2.imread("/home/haobo/Documents/UROP2021/HaoboSeg/train_m/06042021P1_1_slice040time005.png")
a = np.uint8(0.8*a)
a[..., 0] = np.uint8(a[...,0] + b[...,0]*50)
cv2.imshow('', a)
cv2.waitKey()
cv2.destroyAllWindows()
